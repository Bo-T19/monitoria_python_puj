# %% [markdown]
# # Pandas 🐼

# %%
#Importar librería
import pandas as pd

# %% [markdown]
# ## ¿Cómo leer el archivo con pandas?

# %%
#Leer excel
df_colegios=pd.read_excel('LISTADO_COLEGIOS_BOGOTA_20250820.xlsx', sheet_name='Data')

# %%
#Ver las distintas opciones que tiene read_excel
help(pd.read_excel)
# Out:
# Help on function read_excel in module pandas.io.excel._base:
#
# ...

# %%
df_colegios
# Out:
#        año secretaria             nombreestablecimiento    zona  \
# 0     2016     BOGOTA               GIMN NUEVO  SIDAUTO  URBANA
# 1     2016     BOGOTA     JARD INF LA CASITA DE CHENANO  URBANA
# 2     2016     BOGOTA          ACADEMIA REAL PARA NIÑOS  URBANA
# 3     2016     BOGOTA               COL BILING RICHMOND  URBANA
# 4     2016     BOGOTA  COL COOP MONSEÑOR ISMAEL PERDOMO  URBANA
# ...    ...        ...                               ...     ...
# 2399  2016     BOGOTA       COL LOS ANGELES DE HELVETIA  URBANA
# 2400  2016     BOGOTA            INST MODERNO EL LIBANO  URBANA
# 2401  2016     BOGOTA   LIC INF EL MUNDO DEL NIÑO FELIZ  URBANA
# 2402  2016     BOGOTA           LIC PSICOPEDAG ENGATIVA  URBANA
# 2403  2016     BOGOTA   COL UNID RESIDENCIAL COLSEGUROS  URBANA
#
#                      direccion  \
# 0                KR 90 A 91 96
# 1      AV LAS AMERICAS 69 B 59
# 2          CL 42 A 87 I 10 SUR
# 3                 KR 53 222 76
# 4          DG 62 G SUR 72 A 41
# ...

# %%
#Información de todas mis columnas
df_colegios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   año                        2404 non-null   int64
#  1   secretaria                 2404 non-null   object
#  2   nombreestablecimiento      2404 non-null   object
#  3   zona                       2404 non-null   object
#  4   direccion                  2404 non-null   object
#  5   telefono                   2342 non-null   object
#  6   nombre_Rector              2404 non-null   object
#  7   tipo_Establecimiento       2404 non-null   object
#  8   etnias                     71 non-null     object
#  9   sector                     0 non-null      float64
#  10  genero                     0 non-null      float64
#  11  niveles                    2388 non-null   object
#  12  jornadas                   2391 non-null   object
# ...

# %%
#Información de solo una columna
df_colegios['secretaria']
# Out:
# 0       BOGOTA
# 1       BOGOTA
# 2       BOGOTA
# 3       BOGOTA
# 4       BOGOTA
#          ...
# 2399    BOGOTA
# 2400    BOGOTA
# 2401    BOGOTA
# 2402    BOGOTA
# 2403    BOGOTA
# Name: secretaria, Length: 2404, dtype: object

# %% [markdown]
# ## Filtrado y ordenamiento de un dataframe

# %%
#Filtrado de elementos

df_colegios_rurales=df_colegios[df_colegios['zona']=='RURAL']
df_colegios_rurales
# Out:
#        año secretaria                              nombreestablecimiento  \
# 14    2016     BOGOTA                               COL GIMN EL PORTILLO
# 53    2016     BOGOTA                                      LIC CAMBRIDGE
# 152   2016     BOGOTA                          COLEGIO RUR CHIZACA (CED)
# 166   2016     BOGOTA                     COLEGIO RUR EL CURUBITAL (CED)
# 167   2016     BOGOTA                           COLEGIO EL DESTINO (IED)
# 168   2016     BOGOTA                          COLEGIO RUR EL HATO (CED)
# 177   2016     BOGOTA                              COLEGIO EL UVAL (IED)
# 208   2016     BOGOTA                     COLEGIO RUR LA ARGENTINA (CED)
# 215   2016     BOGOTA                       COLEGIO RUR LA MAYORIA (CED)
# 218   2016     BOGOTA                     COLEGIO RUR LAS MERCEDES (CED)
# 222   2016     BOGOTA                    COLEGIO RUR LA UNION USME (CED)
# 227   2016     BOGOTA                        COLEGIO RUR LOS ANDES (CED)
# ...

# %%
#Colegios cuyo nombre contiene "ENSEÑANZA"
df_colegios_enseñanza=df_colegios[df_colegios['nombreestablecimiento'].str.contains('ENSEÑANZA')]
df_colegios_enseñanza
# Out:
#        año secretaria                      nombreestablecimiento    zona  \
# 966   2016     BOGOTA                          FUND LA ENSEÑANZA  URBANA
# 991   2016     BOGOTA                GIMN DE ENSEÑANZA LA SABANA  URBANA
# 1137  2016     BOGOTA    INST EXPERIMENTAL DE ENSEÑANZA PRACTICA  URBANA
# 1261  2016     BOGOTA  INST SOCIAL NOCT DE ENSEÑANZA MEDIA ISNEM  URBANA
# 1470  2016     BOGOTA                      LIC LA REAL ENSEÑANZA  URBANA
# 1893  2016     BOGOTA                        COL DE LA ENSEÑANZA  URBANA
# 2170  2016     BOGOTA           GIMN EL CARRUSEL DE LA ENSEÑANZA  URBANA
#
#                   direccion            telefono  \
# 966           KR 7 A 186 63  6711598 -- 6681847
# 991   CR. 65B NO. 61-20 SUR             2042612
# 1137   TR. 84 NO.42A-04 SUR             2735605
# 1261        CL 81 SUR 42 09             7172495
# 1470           CL 139 38 13             6272236
# 1893           AC 201 67 12             7430535
# ...

# %%
#Dos condiciones al mismo tiempo
df_colegios[(df_colegios['numero_de_Sedes']>1) & (  df_colegios['calendario']=='A')]
# Out:
#        año secretaria                              nombreestablecimiento  \
# 89    2016     BOGOTA     COLEGIO EXTERNADO NACIONAL CAMILO TORRES (IED)
# 92    2016     BOGOTA                COLEGIO CAMPESTRE MONTE VERDE (IED)
# 112   2016     BOGOTA          COLEGIO INTEGRADO DE FONTIBON IBEP  (IED)
# 114   2016     BOGOTA             COLEGIO ENTRE NUBES SUR ORIENTAL (IED)
# 116   2016     BOGOTA                            COLEGIO ACACIA II (IED)
# ...    ...        ...                                                ...
# 1248  2016     BOGOTA   COLEGIO INSTITUTO TECNICO  JUAN DEL CORRAL (IED)
# 1249  2016     BOGOTA   COLEGIO INSTITUTO TECNICO  LAUREANO GOMEZ  (IED)
# 1253  2016     BOGOTA                COLEGIO SAN FRANCISCO DE ASIS (IED)
# 1267  2016     BOGOTA  COLEGIO INSTITUTO TECNICO INDUSTRIAL PILOTO (IED)
# 1569  2016     BOGOTA               COLEGIO POLICARPA SALAVARRIETA (IED)
#
#         zona                direccion  \
# 89    URBANA               KR 7 33 64
# ...

# %%
#Ordenar datos

pd.set_option('display.max_columns', None)
df_colegios.sort_values(by=['prestador_de_Servicio','nombre_Rector'], ascending=[True,True]).head(50)
# Out:
#        año secretaria                       nombreestablecimiento    zona  \
# 58    2016     BOGOTA            ATENEO INTEGRAL ANA B. DE FLOREZ  URBANA
# 496   2016     BOGOTA                 COLEGIO COLSUBSIDIO CHICALÁ  URBANA
# 68    2016     BOGOTA                BTO PARA ADULTOS COLSUBSIDIO  URBANA
# 2228  2016     BOGOTA          LIC Y JARD INF FANTASIAS DE PIOLIN  URBANA
# 492   2016     BOGOTA                   COLEGIO COLSUBSIDIO NORTE  URBANA
# 1416  2016     BOGOTA                         LIC CAMPESTRE CAFAM  URBANA
# 491   2016     BOGOTA               COLEGIO COLSUBSIDIO CIUDADELA  URBANA
# 482   2016     BOGOTA                                   COL CAFAM  URBANA
# 1679  2016     BOGOTA              INSTITUTO EDUCATIVO FUTURO HOY  URBANA
# 963   2016     BOGOTA                             COL FUND LA PAZ  URBANA
# 503   2016     BOGOTA                   COL COMUNAL LAS ORQUIDEAS  URBANA
# 795   2016     BOGOTA                      COL COOP DE LOS ALAMOS  URBANA
# ...

# %%
#Muestreme los primeros 20 colegios
df_colegios.head(20)
# Out:
#      año secretaria                            nombreestablecimiento    zona  \
# 0   2016     BOGOTA                              GIMN NUEVO  SIDAUTO  URBANA
# 1   2016     BOGOTA                    JARD INF LA CASITA DE CHENANO  URBANA
# 2   2016     BOGOTA                         ACADEMIA REAL PARA NIÑOS  URBANA
# 3   2016     BOGOTA                              COL BILING RICHMOND  URBANA
# 4   2016     BOGOTA                 COL COOP MONSEÑOR ISMAEL PERDOMO  URBANA
# 5   2016     BOGOTA                                 GIMN LA ARBOLEDA  URBANA
# 6   2016     BOGOTA           INSTITUCION EDUCATIVA SAN NICOLAS LTDA  URBANA
# 7   2016     BOGOTA                        COLEGIO BILINGÜE INTEGRAL  URBANA
# 8   2016     BOGOTA                              COL GEORGE WILLIAMS  URBANA
# 9   2016     BOGOTA      CENT EDUC MI TALLER CREATIVO NUEVAS ESPIGAS  URBANA
# 10  2016     BOGOTA                                JARD INF STANFORD  URBANA
# ...

# %%
#Muestreme los últimos 20 colegios
df_colegios.tail(20)
# Out:
#        año secretaria                              nombreestablecimiento  \
# 2384  2016     BOGOTA                                  GUARD JARD PIOLIN
# 2385  2016     BOGOTA                           PREESC MI PEQUEÑO JARDIN
# 2386  2016     BOGOTA                                  COL DOMINGO SAVIO
# 2387  2016     BOGOTA                      LIC SANTA MARIA DE LA RIVIERA
# 2388  2016     BOGOTA  INSTITUTO PSICOPEDAGOGICO ANA MARIA DE LOS ANG...
# 2389  2016     BOGOTA                     INST PSICOPEDAG COLOMBIA NUEVA
# 2390  2016     BOGOTA                                      COL LA COLINA
# 2391  2016     BOGOTA                                    LIC NUEVO CHILE
# 2392  2016     BOGOTA                                         COL INCADE
# 2393  2016     BOGOTA                            COL ESTUDIANTIL CHUNIZA
# 2394  2016     BOGOTA                         INST PEDAG FEDERICO BALART
# 2395  2016     BOGOTA                                COL TIRSO DE MOLINA
# ...

# %%
df_colegios=df_colegios.sort_values(by=['nombreestablecimiento'], ascending=True).head(50)
df_colegios.reset_index(inplace=True)
df_colegios
# Out:
#     index   año secretaria                              nombreestablecimiento  \
# 0     113  2016     BOGOTA              ACAD AMERICANA DE SISTEMAS Y COMERCIO
# 1      11  2016     BOGOTA                      ACAD CENTRAL DE SISTEMAS ACSI
# 2      35  2016     BOGOTA                          ACAD LA SALLE SAN BENILDO
# 3      40  2016     BOGOTA                          ACAD MILIT MARISCAL SUCRE
# 4       2  2016     BOGOTA                           ACADEMIA REAL PARA NIÑOS
# 5      34  2016     BOGOTA                                     ALLEGRO PREESC
# 6    1620  2016     BOGOTA                             ASPAEN GIMNASIO IRAGUA
# 7      58  2016     BOGOTA                   ATENEO INTEGRAL ANA B. DE FLOREZ
# 8      59  2016     BOGOTA                                  ATENEO JUAN EUDES
# 9     889  2016     BOGOTA                                BTO DE ADULTOS UNAD
# 10     68  2016     BOGOTA                       BTO PARA ADULTOS COLSUBSIDIO
# ...

# %%
#Traerme una fila en específico
df_colegios.iloc[1:11]
# Out:
#     index   año secretaria             nombreestablecimiento    zona  \
# 1      11  2016     BOGOTA     ACAD CENTRAL DE SISTEMAS ACSI  URBANA
# 2      35  2016     BOGOTA         ACAD LA SALLE SAN BENILDO  URBANA
# 3      40  2016     BOGOTA         ACAD MILIT MARISCAL SUCRE  URBANA
# 4       2  2016     BOGOTA          ACADEMIA REAL PARA NIÑOS  URBANA
# 5      34  2016     BOGOTA                    ALLEGRO PREESC  URBANA
# 6    1620  2016     BOGOTA            ASPAEN GIMNASIO IRAGUA  URBANA
# 7      58  2016     BOGOTA  ATENEO INTEGRAL ANA B. DE FLOREZ  URBANA
# 8      59  2016     BOGOTA                 ATENEO JUAN EUDES  URBANA
# 9     889  2016     BOGOTA               BTO DE ADULTOS UNAD  URBANA
# 10     68  2016     BOGOTA      BTO PARA ADULTOS COLSUBSIDIO  URBANA
#
#               direccion                                  telefono  \
# 1      AV CARACAS 68 11      2172538 / 2350146 /2352887 / 3474968
# 2           KR 7 172 85             6711955 -- 6718299 -- 6797687
# ...

# %% [markdown]
# ## Agregaciones

# %%
precipitaciones=pd.read_excel('Precipitaciones_Totales_Mensuales_20250820.xlsx')

precipitaciones
# Out:
#               ESTACIÓN   CÓDIGO      X=N      Y=E MUNICIPIO       CUENCA  \
# 0        Pajas Blancas  2119022   973320   944710      Nilo    R. Paguey
# 1        Pajas Blancas  2119022   973320   944710      Nilo    R. Paguey
# 2        Pajas Blancas  2119022   973320   944710      Nilo    R. Paguey
# 3        Pajas Blancas  2119022   973320   944710      Nilo    R. Paguey
# 4        Pajas Blancas  2119022   973320   944710      Nilo    R. Paguey
# ...                ...      ...      ...      ...       ...          ...
# 6191   Bombas Sesquilé  2120187  1049890  1031100  Sesquilé  Emb. Tominé
# 6192  Campamento Ubaté  2401115  1029476  1077409     Ubaté     R. Ubaté
# 6193       Los Tiestos  2306039  1084049   963347  La Palma     Rionegro
# 6194  Campamento Ubaté  2401115  1029476  1077409     Ubaté     R. Ubaté
# 6195         Los Pinos  2401116  1000000  1000000    Suesca  Lag. Suesca
#
#        AÑO  ENERO  FEBRERO  MARZO  ABRIL   MAYO  JUNIO  JULIO  AGOSTO  \
# ...

# %%
precipitaciones_filtrado=precipitaciones[['ESTACIÓN','MUNICIPIO', 'AÑO', 'ENERO','FEBRERO', 'MARZO', 'ABRIL', 'MAYO', 'JUNIO', 'JULIO', 'AGOSTO', 'SEPTIEMBRE', 'OCTUBRE', 'NOVIEMBRE', 'DICIEMBRE']]

# %%
precipitaciones_agrupado=precipitaciones_filtrado.groupby(['MUNICIPIO','ESTACIÓN']).mean()

# %% [markdown]
# ## Guardar mi dataframe

# %%
precipitaciones_agrupado.to_excel('PRECIPITACIONES.xlsx',sheet_name="DATA")

help(precipitaciones_agrupado.to_excel)
# Out:
# Help on method to_excel in module pandas.core.generic:
#
# to_excel(excel_writer: 'FilePath | WriteExcelBuffer | ExcelWriter', *, sheet_name: 'str' = 'Sheet1', na_rep: 'str' = '', float_format: 'str | None' = None, columns: 'Sequence[Hashable] | None' = None, header: 'Sequence[Hashable] | bool_t' = True, index: 'bool_t' = True, index_label: 'IndexLabel | None' = None, startrow: 'int' = 0, startcol: 'int' = 0, engine: "Literal['openpyxl', 'xlsxwriter'] | None" = None, merge_cells: 'bool_t' = True, inf_rep: 'str' = 'inf', freeze_panes: 'tuple[int, int] | None' = None, storage_options: 'StorageOptions | None' = None, engine_kwargs: 'dict[str, Any] | None' = None) -> 'None' method of pandas.core.frame.DataFrame instance
#     Write object to an Excel sheet.
#
#     To write a single object to an Excel .xlsx file it is only necessary to
#     specify a target file name. To write to multiple sheets it is necessary to
# ...

# %% [markdown]
# ## Ejemplo transacciones

# %%
transacciones = pd.read_excel('Transacciones_1000.xlsx')
topes=pd.read_excel('Topes.xlsx')

# %%
topes
# Out:
#    Id Nombre persona  Tope transacciones
# 0   1            Ana               18428
# 1   2           Luis               31790
# 2   3         Carlos          1000000000
# 3   4          Marta           100000000
# 4   5          Sofía               20023
# 5   6          Pedro               43275
# 6   7          Lucía               58046
# 7   8         Andrés               18863
# 8   9        Valeria               56269
# 9  10          Jorge               38800

# %%
transacciones['Mes']=transacciones['Fecha'].dt.month
transacciones_limpio=transacciones[['Nombre persona','Transacción','Mes']]

transacciones_agrupadas=transacciones_limpio.groupby(['Nombre persona','Mes']).sum()

df_final = transacciones_agrupadas.merge(topes, on='Nombre persona', how='left')

df_final['Pasó del tope'] = df_final['Transacción'] > df_final['Tope transacciones']

df_final
# Out:
#    Nombre persona  Transacción  Id  Tope transacciones  Pasó del tope
# 0             Ana       970492   1               18428           True
# 1             Ana       935978   1               18428           True
# 2             Ana      1039410   1               18428           True
# 3          Andrés      1145032   8               18863           True
# 4          Andrés      1216271   8               18863           True
# 5          Andrés       955111   8               18863           True
# 6          Carlos       900288   3          1000000000          False
# 7          Carlos       849966   3          1000000000          False
# 8          Carlos      1026586   3          1000000000          False
# 9           Jorge       831098  10               38800           True
# 10          Jorge       829287  10               38800           True
# 11          Jorge      1063970  10               38800           True
# ...
